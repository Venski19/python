# %% [markdown]
# <a href="https://colab.research.google.com/github/Venski19/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#**aula 1**

# %% [markdown]
# #**aula 1** ⛏: 👾

# %%
ano = "IX"
print(ano, " competição de progamação dá Start")
# Out:
# IX  competição de progamação dá Start

# %% [markdown]
# #**aula 2** ⛓ ⏰ ⬛

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46

# %% [markdown]
# #**AULA 3** ㊗: ♦ ⌛

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2999363842.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3 figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #**AULA 4** ⛲ ⛳ 🏖

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# #**AULA 5**  ⚓ ⏬ ☕
#
# > Adicionar aspas

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} // {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3175656577.py in <cell line: 0>()
#       2     for contador in range(1, 11):  # Gera números de 1 a 10
#       3         print(f"{numero} // {contador} = {numero // contador}")
# ----> 4 numero = int(input("Digite um número para ver sua tabuada: "))
#       5 tabuada(numero)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #**AULA 6** ⛹ Ⓜ ⛪

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python! \n 'Python é como poesia para programadores — simples, elegante e poderosa em cada linha de código' ")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript \n 'JavaScript é a linguagem dinâmica da web, que dá vida e interatividade a sites e aplicações.")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática!\n 'A Matemática é a linguagem universal que desvenda os padrões e a lógica que governam o universo.")
else:
    print(f" Que pena, {nome}, não sei falar dess assunto")
# Out:
# olá, sou seu assistente virtual
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1413451873.py in <cell line: 0>()
#       1 print("olá, sou seu assistente virtual")
# ----> 2 nome = input ("digite seu nome: ")
#       3 print(f"olá{nome}, em que posso ajudar?")
#       4 resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
#       5 if resposta =="python":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# #**AULA 7** ⛽ ➖ ⛰ listas

# %%
import random
dica = [
    "🚀O começo é agora: Transforme a inércia em impulso e dê o seu melhor primeiro passo",
    "💡Seja a energia que você quer atrair. Mantenha o ritmo e a consistência",
    "✨Chegamos à metade! Respire fundo, ajuste a rota se preciso e mantenha o foco na meta",
    "💪A persistência é a chave. Lembre-se do porquê você começou e avance com determinação",
    "🏆Seu esforço da semana merece reconhecimento. Finalize com excelência e prepare-se para recarregar",
    "🧭Não é sobre a velocidade, mas sobre a direção. Aproveite para refletir e planejar a próxima jornada",
    "💖Acalme a mente e recarregue o espírito. Um novo ciclo de oportunidades espera por você amanhã",

]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
  elif pedido == "sair":
    print("até a próxima! \n")
    break
  else:
    print("omando inválido. tente novmente. \n")
    break
